# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2664.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2539.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1231.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1017.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2437.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2015.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2300.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2673.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2823.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1522.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2064.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/641.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1088.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/173.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2851.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2448.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1746.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1958.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1479.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/815.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1794.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1727.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1684.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1814.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/491.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2982.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2276.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1457.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1924.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1084.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/718.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/709.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2690.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/889.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/379.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/780.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/248.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1680.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1675.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2619.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2273.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/94.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2969.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2772.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/480.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2256.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1145.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2021.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1944.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/236.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1012.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2970.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2518.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2176.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1343.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2347.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/771.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2884.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2631.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/675.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/340.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/48.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2525.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1948.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1878.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2211.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/513.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2947.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2976.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1037.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/677.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/350.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2009.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/761.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1258.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2565.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/314.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1023.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1337.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/655.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/227.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/762.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2803.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/726.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2199.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1630.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2920.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/238.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/61.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2731.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/377.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1961.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1798.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2324.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/581.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1782.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/222.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/330.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2742.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/511.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/579.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/278.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2146.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1863.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/927.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/303.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/37.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/231.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1048.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2367.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2559.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/645.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2270.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1703.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/348.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/449.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2718.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2779.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/353.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2645.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/621.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2134.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1726.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/148.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/990.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2844.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/403.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2661.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1590.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1995.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2121.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1855.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1813.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1000.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2346.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2269.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1604.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/352.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2522.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/35.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2302.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2030.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/232.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/817.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1827.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/334.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/177.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2533.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2637.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2990.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1081.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1780.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1992.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2058.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/142.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2365.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/834.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1176.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1914.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/754.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/407.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2767.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2978.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/104.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2013.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1690.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1413.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/384.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2011.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1670.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/376.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/543.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1312.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/737.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1156.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1004.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2069.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2675.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/133.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/70.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1754.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1529.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/162.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/419.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/951.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1705.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2169.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2410.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/940.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/517.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1032.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/398.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/634.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1513.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/186.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/778.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/73.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/870.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/933.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2741.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2513.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1633.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/92.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1328.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2182.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2381.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1989.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/542.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2376.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2136.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/766.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2003.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/315.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/436.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/359.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/261.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1214.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1931.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1673.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2051.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1532.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1820.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2537.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1918.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/901.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1096.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2430.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2829.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2893.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/153.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1578.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1954.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1500.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1846.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2462.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1959.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2218.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2902.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2099.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1320.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/167.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1348.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2640.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/628.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2041.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/506.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2156.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1147.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1375.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1452.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2094.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/441.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/928.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/562.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/681.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2668.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2582.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1266.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1542.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2526.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1206.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1064.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/204.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/646.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1179.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2233.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/75.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1128.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/296.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2184.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1494.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2388.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1364.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1334.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1576.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1072.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2832.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1123.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1808.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2801.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/744.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2428.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1314.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/538.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1301.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/651.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/899.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1907.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/270.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2607.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/89.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/385.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2096.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/768.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/872.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2079.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/338.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/333.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/164.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1168.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1118.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1867.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/752.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2795.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/550.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1326.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/521.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1275.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2355.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2143.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1789.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/11.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1668.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1036.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/615.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/416.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2495.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1952.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/994.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/881.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/605.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/707.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2854.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/351.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1010.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1910.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1208.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/213.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2577.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1695.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/411.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2183.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/505.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1445.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/114.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1698.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1871.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1307.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/930.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2278.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/302.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/185.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1870.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/240.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1483.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/811.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/317.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2653.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1294.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1530.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2026.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1678.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1514.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1041.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2702.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/281.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2901.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/344.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1967.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1649.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2519.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1268.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1627.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/457.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/493.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1329.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/759.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/907.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2489.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1071.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/362.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2336.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2751.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1148.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/176.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2106.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/660.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/727.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1625.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2088.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/95.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2228.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/432.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/895.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1161.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2594.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/97.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1351.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/124.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2429.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/119.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1227.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2747.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/256.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2861.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/791.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/654.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/100.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1381.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/211.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1241.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2345.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2696.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/500.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2333.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/322.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1584.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2372.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1622.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/76.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1269.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1197.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/193.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2541.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2841.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/608.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1893.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1955.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/191.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/420.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/528.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/163.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/31.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2523.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2491.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2750.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2301.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1779.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/623.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/969.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2349.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1097.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/642.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2558.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1401.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1594.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/825.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1420.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2517.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1882.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2943.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2280.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1122.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1018.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1220.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1469.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2017.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1991.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/138.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/629.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2380.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2344.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2113.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1333.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2213.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/396.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/4.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1405.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2095.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/796.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/844.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/225.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1371.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/561.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2028.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2472.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/588.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/492.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2370.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2853.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2609.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/669.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2037.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2173.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1315.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1868.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1219.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1887.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1482.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2534.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/192.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2463.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2067.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2340.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2806.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2466.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1249.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2097.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/43.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1137.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/229.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1598.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/992.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1783.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/635.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2040.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1844.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1135.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2405.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2242.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/962.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/129.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1946.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/331.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1885.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1243.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1067.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/313.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/966.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/672.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2371.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/820.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1558.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1349.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1279.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1733.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1740.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/580.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/345.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2611.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2053.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1694.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/171.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/682.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1113.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/903.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2066.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2786.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1154.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1984.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1755.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1616.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1913.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/287.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1339.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1187.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1103.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2435.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1199.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/324.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/145.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1255.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2864.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/863.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1283.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2904.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1108.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1430.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2717.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1548.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/40.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1322.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2875.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2082.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1528.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/209.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2855.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2626.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1751.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/197.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2544.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1874.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1970.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1240.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1130.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/982.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1507.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/445.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1006.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2776.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/575.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/311.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1347.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/959.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1771.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1940.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/33.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/126.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/876.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2761.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/147.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/973.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2599.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/688.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1212.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1165.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2103.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/468.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2816.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2250.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/326.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2252.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/357.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/2490.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/without_mask/1361.png
# ...
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/253.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/206.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1034.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1834.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2849.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/789.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1894.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2643.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1365.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/557.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2167.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1274.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2163.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/980.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1309.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1175.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2985.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/613.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/600.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/874.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2583.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/381.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/342.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1252.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1074.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2458.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1267.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1866.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2225.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/346.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1497.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2881.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2939.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/134.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/721.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/898.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1124.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2258.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2399.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2288.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1912.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1938.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1781.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2227.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2246.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/694.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2734.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/590.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2504.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2972.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1172.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/566.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2837.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/921.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1426.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1957.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1765.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1762.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/259.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2159.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1889.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1579.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2442.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/25.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/871.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1613.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/285.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1297.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/341.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/54.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1160.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/462.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/851.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/558.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1861.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1350.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/111.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/611.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2055.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2618.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1644.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1825.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/887.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2586.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2035.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/62.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2474.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/205.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1373.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1265.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/699.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2414.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1711.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/369.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/750.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1262.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2610.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2033.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/963.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/141.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/693.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2232.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2361.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/532.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1408.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/309.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/560.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1211.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/19.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/110.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/544.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/308.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2161.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2831.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1988.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2078.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1659.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2422.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1911.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1998.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2339.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/26.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2073.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/568.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1960.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2677.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/918.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2004.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/388.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1916.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2739.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1453.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2725.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/79.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/633.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/824.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1396.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2764.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2027.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2016.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1609.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2632.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/729.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2852.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2804.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1414.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1477.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/883.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2621.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1709.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/257.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2766.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2915.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2663.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2139.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/993.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1281.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/305.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2293.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2894.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1676.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/477.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/42.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/175.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1261.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1621.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/961.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1551.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/518.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2155.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1602.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2918.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/957.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1876.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/226.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1493.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2879.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2179.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2570.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/428.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2927.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2264.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/217.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2964.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1424.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1710.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2652.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/1330.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2708.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/867.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2693.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/821.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/494.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2383.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/837.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/659.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2210.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/418.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/452.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2627.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/981.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/948.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/2392.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/306.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/497.png
# /kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset/with_mask/304.png

# %% [markdown]
# ### import all required libraries

# %%
import matplotlib.pyplot as plt
from PIL import Image
from keras.models import Sequential
import keras, shutil
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, AveragePooling2D, Input, BatchNormalization, Activation, Add
from keras.initializers import glorot_uniform
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ##  Load the dataset

# %%
path = "/kaggle/input/d/vijaykumar1799/face-mask-detection/Dataset"
print(os.listdir(path))

# print number of samples in each class
print("with_mask samples: ", len(os.listdir(os.path.join(path, 'with_mask'))))
print("without_mask samples: ", len(os.listdir(os.path.join(path, "without_mask"))))
# Out:
# ['without_mask', 'mask_weared_incorrect', 'with_mask']
# with_mask samples:  2994
# without_mask samples:  2994

# %%
os.mkdir('/kaggle/temp')
os.mkdir('/kaggle/temp/with_mask')
os.mkdir('/kaggle/temp/without_mask')

for filename1, filename2 in zip(os.listdir(path + '/with_mask'), os.listdir(path + '/without_mask')):
    shutil.copy(os.path.join(path, 'with_mask/' + filename1), '/kaggle/temp/with_mask')
    shutil.copy(os.path.join(path, 'without_mask/' + filename2), '/kaggle/temp/without_mask')

# %% [markdown]
# as you can see that with_mask class contains 2994 samples and without_mask contains 2994 samples.
#
# Now, I will create training and validation set. To create training and validation set, first i will create the temp directory and inside this directory i will create the "train" and "val" directory. Both directories ('train' and 'val') will also have the sub directories 'with_mask' and 'without_mask'.
#
# After that I will move 2400 images from each class to train directory and rest of images will be used as the validation set which i will move to the val directory.
#
# It means that out of 5988 samples (images), 4800 samples will be used for the training set and 1188 (about 20%) will be used as the validation set.

# %%
# create necessary directories for training and validation set
temp_path = '/kaggle/temp/'
#os.mkdir(temp_path)

os.mkdir(os.path.join(temp_path, 'train'))
os.mkdir(os.path.join(temp_path, 'train/with_mask'))
os.mkdir(os.path.join(temp_path, 'train/without_mask'))

os.mkdir(os.path.join(temp_path, 'val'))
os.mkdir(os.path.join(temp_path, 'val/with_mask'))
os.mkdir(os.path.join(temp_path, 'val/without_mask'))

# print directories
print(os.listdir(temp_path))
# Out:
# ['with_mask', 'without_mask', 'train', 'val']

# %%
# Move the data from '/kaggle/input/face-mask-detection/data' to 'train' and 'val' directories

path = '/kaggle/temp/'

# move to 'train' directory
for filename in os.listdir(os.path.join(path, 'with_mask'))[0:2400]:
    src_path = os.path.join(path, 'with_mask/' + filename)
    dst_path = os.path.join(temp_path, 'train/with_mask/')
    shutil.move(src_path, dst_path)

for filename in os.listdir(os.path.join(path, 'without_mask'))[0:2400]:
    src_path = os.path.join(path , 'without_mask/' + filename)
    dst_path = os.path.join(temp_path, 'train/without_mask/')
    shutil.move(src_path, dst_path)
    
# move rest of the files to the 'val' directory
for filename in os.listdir(os.path.join(path, 'with_mask')):
    src_path = os.path.join(path, 'with_mask/' + filename)
    dst_path = os.path.join(temp_path, 'val/with_mask/')
    shutil.move(src_path, dst_path)
    
for filename in os.listdir(os.path.join(path, 'without_mask')):
    src_path = os.path.join(path, 'without_mask/' + filename)
    dst_path = os.path.join(temp_path, 'val/without_mask/')
    shutil.move(src_path, dst_path)

# %%
# remove 'with_mask' and 'without_mask' directory from '/kaggle/temp/'
os.rmdir(path + 'with_mask')
os.rmdir(path + 'without_mask')

print(os.listdir(path))
# Out:
# ['train', 'val']

# %%
# print number of samples in training and validation set
print("\n ---------------  Training samples  ------------------ \n")
print("with_mask samples: ", len(os.listdir(os.path.join(path, 'train/with_mask'))))
print("without_mask samples: ", len(os.listdir(os.path.join(path, 'train/without_mask'))))

print("\n ---------------  Validation samples  --------------------\n")
print("with_mask samples: ", len(os.listdir(os.path.join(path, 'val/with_mask'))))
print("without_mask samples: ", len(os.listdir(os.path.join(path, 'val/without_mask'))))
# Out:
#  ---------------  Training samples  ------------------
#
# with_mask samples:  2400
# without_mask samples:  2400
#
#  ---------------  Validation samples  --------------------
#
# with_mask samples:  594
# without_mask samples:  594

# %%
# to generate more images I will use Image Data Generator
datagen = ImageDataGenerator(rescale = 1.0/255, horizontal_flip = True, 
                            rotation_range = 20, 
                            width_shift_range =  0.2,
                            height_shift_range = 0.2)

train_batch_size = 32
train_dir = '/kaggle/temp/train/'

# create train generator
train_gen = datagen.flow_from_directory(train_dir,
                                       target_size = (224, 224),
                                       batch_size = train_batch_size,
                                       class_mode = 'categorical')

val_batch_size = 32
val_dir = '/kaggle/temp/val/'

# create val generator
val_gen = datagen.flow_from_directory(val_dir,
                                     target_size = (224, 224),
                                     batch_size = val_batch_size,
                                     class_mode = 'categorical')
# Out:
# Found 4800 images belonging to 2 classes.
# Found 1188 images belonging to 2 classes.

# %%
# print label encoding
print(train_gen.class_indices)
# Out:
# {'with_mask': 0, 'without_mask': 1}

# %%
# get number of samples in training set and val set
train_num_samples = 0

for _, _, filenames in os.walk('/kaggle/temp/train/'):
    train_num_samples += len(filenames)
    
val_num_samples = 0

for _, _, filenames in os.walk('/kaggle/temp/val/'):
    val_num_samples += len(filenames)
    
print("train_num_samples: ",train_num_samples)
print("val_num_samples: ",val_num_samples)
# Out:
# train_num_samples:  4800
# val_num_samples:  1188

# %% [markdown]
# ## Visualize images generated by the Image Generator

# %%
x, y = train_gen.next()
# # print(y)
# plt.figure(figsize = (15, 15))

# for i, (img, label) in enumerate(zip(x, y)):
#     plt.subplot(8, 4, i+1)
    
#     if label == 0:
#         plt.title("with mask")
#     else:
#         plt.title("without mask")
        
# #     plt.axis('off')
# #     plt.imshow(img)

# %% [markdown]
# ### Create 50 Layer ResNet Model acrhitecture
# Let's first define the identity_block used in ResNet.
#
# #### Identity Block
# The identity block is the standard block used in ResNets, and corresponds to the case where the input activation (say
# )has the same dimension as the output activation (say
# ).
#
# * Use 0 as the seed for random initialization
# * BatchNorm is normalizing the 'channels' axis

# %%
def identity_block(X, f, filters, stage, block):
    """
    Implementation of the identity block
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    
    Returns:
    X -- output of the identity block, tensor of shape (n_H, n_W, n_C)
    """
    
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X
    
    # First component of main path
    X = Conv2D(filters = F1, kernel_size = (1,1), strides = (1,1), padding = 'valid', 
               name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
    
    # Second component of main path
    X = Conv2D(filters = F2, kernel_size = (f,f), strides = (1,1), padding='same',
              name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)
    
    # Third component of main path
    X = Conv2D(filters = F3, kernel_size = (1,1), strides = (1,1), padding='valid',
              name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name = bn_name_base + '2c')(X)
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

# %% [markdown]
# ### Convolution block
# The ResNet "convolution block" is the second block type. You can use this block when the input and the output dimensions don't match up. The difference with the identity block is that there is a Conv2D layer in the shortcut path.
#
# The Conv2D layer in the shortcut path is used to resize the input X to a different dimension, so that the dimensions match up in the final addition to add the shortcut value back to the main path.
# For example, to reduce the activation dimensions height and width by a factor of 2, you can use a 1x1 convolution with a stride of 2.

# %%
def convolution_block(X, f, filters, stage, block, s=2):
    """
    Implementation of the convolution block
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle Conv's window for the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character , used to name the layers, depending on their position in the network
    s -- integer, specifying the stride to be used
    """
    
    # defining the name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve filters
    F1, F2, F3 = filters
    
    # Save the input
    X_shortcut = X
    
    # First component of main path
    X = Conv2D(filters = F1, kernel_size = (1,1), strides = (s,s), padding='valid',
              name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)
    
    # Second component of main path
    X = Conv2D(filters = F2, kernel_size = (f,f), strides = (1,1), padding='same',
              name=conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)
    
    # Third component of main path
    X = Conv2D(filters = F3, kernel_size = (1,1), strides = (1,1), padding='valid',
              name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base+'2c')(X)
    
    # Shortcut path
    X_shortcut = Conv2D(filters = F3, kernel_size = (1,1), strides = (s,s), padding='valid',
                      name=conv_name_base+'1', kernel_initializer = glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis=3, name=bn_name_base+'1')(X_shortcut)
    
    # Final step, Add shortcut value to main path and pass it through a Relu activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

# %% [markdown]
# ### Building the model
# We now have the necessary blocks to build a very deep ResNet. The details of the ResNet-50 model are as follows:
#
# *  Stage 1:
#  * The 2D convolution has 64 filters of shape (7,7) and uses a stride of (2,2). Its name is "conv1".
#  * BatchNorm is applied to the channels axis of the input
#  * MaxPooling uses a 3x3 window and a (2,2) stride
# * Stage 2:
#  * The convolution block uses three set of filters of size [64,64,256], "f" is 3, "s" is 1 and the block is "a"
#  * The 2 identity blocks use three sets of filters of size [64,64,256], "f" is 3, and the blocks are "b" and "c"
# * Stage 3:
#  * The convolution block uses three set of filters of size [128,128,512], "f" is 3, "s" is 2 and the block is "a"
#  * Three identity blocks use three sets of filters of size [128,128,512], "f" is 3, and the blocks are "b", "c", and "d"
# * Stage 4:
#  * The convolution block uses three sets of filters of size [256,256,1024],"f" is 3, "s" is 2 and the block is "a"
#  * The 5 identity block use three sets of filters of size [256,256,1024], "f" is 3 and the blocks are "b", "c", "d", "e" and "f"
# * Stage 5:
#  * The convolution block uses three sets of filters of size [512,512,2048], "f" is 3, "s" is 2 and the block is "a"
#  * The 2 identity block use three sets of filters of size [512,512,2048], "f" is 3 and the blocks are "b" and "c"
# * The 2D AveragePooling uses a window of shape (2,2) and its name 'avg_pool'.
# * The 'Flatten' layer doesn't have any hyperparameters or name.
# * The Fully Connected (Dense) layers reduces its input to the number of classes using a softmax activation.

# %%
def ResNet50(input_shape=(64, 64, 3), classes=2):
    
    # define the input as a tensor with shape input_shape
    X_input = Input(shape=input_shape)
    
    # Stage 1
    X = Conv2D(filters = 64, kernel_size = (3,3), strides = (1,1), padding='valid',
              name='conv1', kernel_initializer = glorot_uniform(seed=0))(X_input)
    X = BatchNormalization(axis=3, name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D(pool_size=(3,3), strides=(2,2))(X)
    
    # Stage 2
    X = convolution_block(X, f=3, filters=[64,64,256], stage=2, block='a', s=2)
    X = identity_block(X, f=3, filters=[64,64,256], stage=2, block='b')
    X = identity_block(X, f=3, filters=[64,64,256], stage=2, block='c')
    
    # Stage 3
    X = convolution_block(X, f=3, filters=[128,128,512], stage=3, block='a', s=2)
    X = identity_block(X, f=3, filters=[128,128,512],stage=3, block='b')
    X = identity_block(X, f=3, filters=[128,128,512], stage=3, block='c')
    X = identity_block(X, f=3, filters=[128,128,512], stage=3, block='d')
    
    # Stage 4
    X = convolution_block(X, f=3, filters=[256,256,1024], stage=4, block='a', s=2)
    X = identity_block(X, f=3, filters=[256,256,1024], stage=4, block='b')
    X = identity_block(X, f=3, filters=[256,256,1024], stage=4, block='c')
    X = identity_block(X, f=3, filters=[256,256,1024], stage=4, block='d')
    X = identity_block(X, f=3, filters=[256,256,1024], stage=4, block='e')
    X = identity_block(X, f=3, filters=[256,256,1024], stage=4, block='f')
    
    # Stage 5
    X = convolution_block(X, f=3, filters=[512,512,2048], stage=5, block='a', s=2)
    X = identity_block(X, f=3, filters=[512,512,2048], stage=5, block='b')
    X = identity_block(X, f=3, filters=[512,512,2048], stage=5, block='c')
    
    # AVGPool
    X = AveragePooling2D(pool_size=(2,2), padding='same')(X)
    
    # output layer
    X = Flatten()(X)
    X = Dense(units=classes, activation='softmax', name='fc' + str(classes), kernel_initializer=glorot_uniform(seed=0))(X)
    
    # create model
    model = keras.Model(inputs = X_input, outputs=X, name='ResNet50')
    
    return model

# %%
model = ResNet50(input_shape = (224,224,3), classes=2)

# print model summary
model.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1 (Conv2D)                 (None, 222, 222, 64  1792        ['input_1[0][0]']
#                                 )
#
#  bn_conv1 (BatchNormalization)  (None, 222, 222, 64  256         ['conv1[0][0]']
#                                 )
#
#  activation (Activation)        (None, 222, 222, 64  0           ['bn_conv1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 110, 110, 64  0           ['activation[0][0]']
#                                 )
#
#  res2a_branch2a (Conv2D)        (None, 55, 55, 64)   4160        ['max_pooling2d[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 55, 55, 64)  256         ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_1 (Activation)      (None, 55, 55, 64)   0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv2D)        (None, 55, 55, 64)   36928       ['activation_1[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 55, 55, 64)  256         ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 55, 55, 64)   0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv2D)        (None, 55, 55, 256)  16640       ['activation_2[0][0]']
#
#  res2a_branch1 (Conv2D)         (None, 55, 55, 256)  16640       ['max_pooling2d[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 55, 55, 256)  1024       ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 55, 55, 256)  1024       ['res2a_branch1[0][0]']
#  on)
#
#  add (Add)                      (None, 55, 55, 256)  0           ['bn2a_branch2c[0][0]',
#                                                                   'bn2a_branch1[0][0]']
#
#  activation_3 (Activation)      (None, 55, 55, 256)  0           ['add[0][0]']
#
#  res2b_branch2a (Conv2D)        (None, 55, 55, 64)   16448       ['activation_3[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 55, 55, 64)  256         ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_4 (Activation)      (None, 55, 55, 64)   0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv2D)        (None, 55, 55, 64)   36928       ['activation_4[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 55, 55, 64)  256         ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_5 (Activation)      (None, 55, 55, 64)   0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv2D)        (None, 55, 55, 256)  16640       ['activation_5[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 55, 55, 256)  1024       ['res2b_branch2c[0][0]']
#  ion)
#
#  add_1 (Add)                    (None, 55, 55, 256)  0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 55, 55, 256)  0           ['add_1[0][0]']
#
#  res2c_branch2a (Conv2D)        (None, 55, 55, 64)   16448       ['activation_6[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 55, 55, 64)  256         ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_7 (Activation)      (None, 55, 55, 64)   0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv2D)        (None, 55, 55, 64)   36928       ['activation_7[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 55, 55, 64)  256         ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_8 (Activation)      (None, 55, 55, 64)   0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv2D)        (None, 55, 55, 256)  16640       ['activation_8[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 55, 55, 256)  1024       ['res2c_branch2c[0][0]']
#  ion)
#
#  add_2 (Add)                    (None, 55, 55, 256)  0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 55, 55, 256)  0           ['add_2[0][0]']
#
#  res3a_branch2a (Conv2D)        (None, 28, 28, 128)  32896       ['activation_9[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_10 (Activation)     (None, 28, 28, 128)  0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_10[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_11 (Activation)     (None, 28, 28, 128)  0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_11[0][0]']
#
#  res3a_branch1 (Conv2D)         (None, 28, 28, 512)  131584      ['activation_9[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 28, 28, 512)  2048       ['res3a_branch1[0][0]']
#  on)
#
#  add_3 (Add)                    (None, 28, 28, 512)  0           ['bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch1[0][0]']
#
#  activation_12 (Activation)     (None, 28, 28, 512)  0           ['add_3[0][0]']
#
#  res3b_branch2a (Conv2D)        (None, 28, 28, 128)  65664       ['activation_12[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 28, 28, 128)  0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_13[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_14 (Activation)     (None, 28, 28, 128)  0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_14[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3b_branch2c[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 28, 28, 512)  0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 28, 28, 512)  0           ['add_4[0][0]']
#
#  res3c_branch2a (Conv2D)        (None, 28, 28, 128)  65664       ['activation_15[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_16 (Activation)     (None, 28, 28, 128)  0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_16[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_17 (Activation)     (None, 28, 28, 128)  0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_17[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3c_branch2c[0][0]']
#  ion)
#
#  add_5 (Add)                    (None, 28, 28, 512)  0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 28, 28, 512)  0           ['add_5[0][0]']
#
#  res3d_branch2a (Conv2D)        (None, 28, 28, 128)  65664       ['activation_18[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 28, 28, 128)  512        ['res3d_branch2a[0][0]']
#  ion)
#
#  activation_19 (Activation)     (None, 28, 28, 128)  0           ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv2D)        (None, 28, 28, 128)  147584      ['activation_19[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 28, 28, 128)  512        ['res3d_branch2b[0][0]']
#  ion)
#
#  activation_20 (Activation)     (None, 28, 28, 128)  0           ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv2D)        (None, 28, 28, 512)  66048       ['activation_20[0][0]']
#
#  bn3d_branch2c (BatchNormalizat  (None, 28, 28, 512)  2048       ['res3d_branch2c[0][0]']
#  ion)
#
#  add_6 (Add)                    (None, 28, 28, 512)  0           ['bn3d_branch2c[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_21 (Activation)     (None, 28, 28, 512)  0           ['add_6[0][0]']
#
#  res4a_branch2a (Conv2D)        (None, 14, 14, 256)  131328      ['activation_21[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_22 (Activation)     (None, 14, 14, 256)  0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_22[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_23 (Activation)     (None, 14, 14, 256)  0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_23[0][0]']
#                                 )
#
#  res4a_branch1 (Conv2D)         (None, 14, 14, 1024  525312      ['activation_21[0][0]']
#                                 )
#
#  bn4a_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4a_branch2c[0][0]']
#  ion)                           )
#
#  bn4a_branch1 (BatchNormalizati  (None, 14, 14, 1024  4096       ['res4a_branch1[0][0]']
#  on)                            )
#
#  add_7 (Add)                    (None, 14, 14, 1024  0           ['bn4a_branch2c[0][0]',
#                                 )                                 'bn4a_branch1[0][0]']
#
#  activation_24 (Activation)     (None, 14, 14, 1024  0           ['add_7[0][0]']
#                                 )
#
#  res4b_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_24[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4b_branch2a[0][0]']
#  ion)
#
#  activation_25 (Activation)     (None, 14, 14, 256)  0           ['bn4b_branch2a[0][0]']
#
#  res4b_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_25[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4b_branch2b[0][0]']
#  ion)
#
#  activation_26 (Activation)     (None, 14, 14, 256)  0           ['bn4b_branch2b[0][0]']
#
#  res4b_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_26[0][0]']
#                                 )
#
#  bn4b_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4b_branch2c[0][0]']
#  ion)                           )
#
#  add_8 (Add)                    (None, 14, 14, 1024  0           ['bn4b_branch2c[0][0]',
#                                 )                                 'activation_24[0][0]']
#
#  activation_27 (Activation)     (None, 14, 14, 1024  0           ['add_8[0][0]']
#                                 )
#
#  res4c_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_27[0][0]']
#
#  bn4c_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4c_branch2a[0][0]']
#  ion)
#
#  activation_28 (Activation)     (None, 14, 14, 256)  0           ['bn4c_branch2a[0][0]']
#
#  res4c_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_28[0][0]']
#
#  bn4c_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4c_branch2b[0][0]']
#  ion)
#
#  activation_29 (Activation)     (None, 14, 14, 256)  0           ['bn4c_branch2b[0][0]']
#
#  res4c_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_29[0][0]']
#                                 )
#
#  bn4c_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4c_branch2c[0][0]']
#  ion)                           )
#
#  add_9 (Add)                    (None, 14, 14, 1024  0           ['bn4c_branch2c[0][0]',
#                                 )                                 'activation_27[0][0]']
#
#  activation_30 (Activation)     (None, 14, 14, 1024  0           ['add_9[0][0]']
#                                 )
#
#  res4d_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_30[0][0]']
#
#  bn4d_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4d_branch2a[0][0]']
#  ion)
#
#  activation_31 (Activation)     (None, 14, 14, 256)  0           ['bn4d_branch2a[0][0]']
#
#  res4d_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_31[0][0]']
#
#  bn4d_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4d_branch2b[0][0]']
#  ion)
#
#  activation_32 (Activation)     (None, 14, 14, 256)  0           ['bn4d_branch2b[0][0]']
#
#  res4d_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_32[0][0]']
#                                 )
#
#  bn4d_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4d_branch2c[0][0]']
#  ion)                           )
#
#  add_10 (Add)                   (None, 14, 14, 1024  0           ['bn4d_branch2c[0][0]',
#                                 )                                 'activation_30[0][0]']
#
#  activation_33 (Activation)     (None, 14, 14, 1024  0           ['add_10[0][0]']
#                                 )
#
#  res4e_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_33[0][0]']
#
#  bn4e_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4e_branch2a[0][0]']
#  ion)
#
#  activation_34 (Activation)     (None, 14, 14, 256)  0           ['bn4e_branch2a[0][0]']
#
#  res4e_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_34[0][0]']
#
#  bn4e_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4e_branch2b[0][0]']
#  ion)
#
#  activation_35 (Activation)     (None, 14, 14, 256)  0           ['bn4e_branch2b[0][0]']
#
#  res4e_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_35[0][0]']
#                                 )
#
#  bn4e_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4e_branch2c[0][0]']
#  ion)                           )
#
#  add_11 (Add)                   (None, 14, 14, 1024  0           ['bn4e_branch2c[0][0]',
#                                 )                                 'activation_33[0][0]']
#
#  activation_36 (Activation)     (None, 14, 14, 1024  0           ['add_11[0][0]']
#                                 )
#
#  res4f_branch2a (Conv2D)        (None, 14, 14, 256)  262400      ['activation_36[0][0]']
#
#  bn4f_branch2a (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4f_branch2a[0][0]']
#  ion)
#
#  activation_37 (Activation)     (None, 14, 14, 256)  0           ['bn4f_branch2a[0][0]']
#
#  res4f_branch2b (Conv2D)        (None, 14, 14, 256)  590080      ['activation_37[0][0]']
#
#  bn4f_branch2b (BatchNormalizat  (None, 14, 14, 256)  1024       ['res4f_branch2b[0][0]']
#  ion)
#
#  activation_38 (Activation)     (None, 14, 14, 256)  0           ['bn4f_branch2b[0][0]']
#
#  res4f_branch2c (Conv2D)        (None, 14, 14, 1024  263168      ['activation_38[0][0]']
#                                 )
#
#  bn4f_branch2c (BatchNormalizat  (None, 14, 14, 1024  4096       ['res4f_branch2c[0][0]']
#  ion)                           )
#
#  add_12 (Add)                   (None, 14, 14, 1024  0           ['bn4f_branch2c[0][0]',
#                                 )                                 'activation_36[0][0]']
#
#  activation_39 (Activation)     (None, 14, 14, 1024  0           ['add_12[0][0]']
#                                 )
#
#  res5a_branch2a (Conv2D)        (None, 7, 7, 512)    524800      ['activation_39[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_40 (Activation)     (None, 7, 7, 512)    0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv2D)        (None, 7, 7, 512)    2359808     ['activation_40[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_41 (Activation)     (None, 7, 7, 512)    0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv2D)        (None, 7, 7, 2048)   1050624     ['activation_41[0][0]']
#
#  res5a_branch1 (Conv2D)         (None, 7, 7, 2048)   2099200     ['activation_39[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 7, 7, 2048)  8192        ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 7, 7, 2048)  8192        ['res5a_branch1[0][0]']
#  on)
#
#  add_13 (Add)                   (None, 7, 7, 2048)   0           ['bn5a_branch2c[0][0]',
#                                                                   'bn5a_branch1[0][0]']
#
#  activation_42 (Activation)     (None, 7, 7, 2048)   0           ['add_13[0][0]']
#
#  res5b_branch2a (Conv2D)        (None, 7, 7, 512)    1049088     ['activation_42[0][0]']
#
#  bn5b_branch2a (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5b_branch2a[0][0]']
#  ion)
#
#  activation_43 (Activation)     (None, 7, 7, 512)    0           ['bn5b_branch2a[0][0]']
#
#  res5b_branch2b (Conv2D)        (None, 7, 7, 512)    2359808     ['activation_43[0][0]']
#
#  bn5b_branch2b (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5b_branch2b[0][0]']
#  ion)
#
#  activation_44 (Activation)     (None, 7, 7, 512)    0           ['bn5b_branch2b[0][0]']
#
#  res5b_branch2c (Conv2D)        (None, 7, 7, 2048)   1050624     ['activation_44[0][0]']
#
#  bn5b_branch2c (BatchNormalizat  (None, 7, 7, 2048)  8192        ['res5b_branch2c[0][0]']
#  ion)
#
#  add_14 (Add)                   (None, 7, 7, 2048)   0           ['bn5b_branch2c[0][0]',
#                                                                   'activation_42[0][0]']
#
#  activation_45 (Activation)     (None, 7, 7, 2048)   0           ['add_14[0][0]']
#
#  res5c_branch2a (Conv2D)        (None, 7, 7, 512)    1049088     ['activation_45[0][0]']
#
#  bn5c_branch2a (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5c_branch2a[0][0]']
#  ion)
#
#  activation_46 (Activation)     (None, 7, 7, 512)    0           ['bn5c_branch2a[0][0]']
#
#  res5c_branch2b (Conv2D)        (None, 7, 7, 512)    2359808     ['activation_46[0][0]']
#
#  bn5c_branch2b (BatchNormalizat  (None, 7, 7, 512)   2048        ['res5c_branch2b[0][0]']
#  ion)
#
#  activation_47 (Activation)     (None, 7, 7, 512)    0           ['bn5c_branch2b[0][0]']
#
#  res5c_branch2c (Conv2D)        (None, 7, 7, 2048)   1050624     ['activation_47[0][0]']
#
#  bn5c_branch2c (BatchNormalizat  (None, 7, 7, 2048)  8192        ['res5c_branch2c[0][0]']
#  ion)
#
#  add_15 (Add)                   (None, 7, 7, 2048)   0           ['bn5c_branch2c[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_48 (Activation)     (None, 7, 7, 2048)   0           ['add_15[0][0]']
#
#  average_pooling2d (AveragePool  (None, 4, 4, 2048)  0           ['activation_48[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 32768)        0           ['average_pooling2d[0][0]']
#
#  fc2 (Dense)                    (None, 2)            65538       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 23,645,570
# Trainable params: 23,592,450
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# ## Compile, Train and Evaluate the model

# %%
# learning rate decay
import tensorflow as tf
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate = 0.001,
                                                         decay_steps = 5,
                                                         decay_rate = 0.2)
# compile the model
model.compile(loss='categorical_crossentropy', 
             optimizer = Adam(learning_rate=0.00002),
             metrics=['accuracy'])

# calculate train_steps and val_steps
train_steps = np.ceil(train_num_samples / train_batch_size)
val_steps = np.ceil(val_num_samples / val_batch_size)
#print(val_steps.dtype)
# train the model
history = model.fit_generator(train_gen,
                             steps_per_epoch = train_steps,
                             epochs = 15,
                             validation_data = val_gen,
                             validation_steps = val_steps)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:20: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/15
# 150/150 [==============================] - 106s 604ms/step - loss: 0.5078 - accuracy: 0.7919 - val_loss: 0.9443 - val_accuracy: 0.5000
# Epoch 2/15
# 150/150 [==============================] - 88s 586ms/step - loss: 0.3127 - accuracy: 0.8994 - val_loss: 0.7211 - val_accuracy: 0.6027
# Epoch 3/15
# 150/150 [==============================] - 89s 591ms/step - loss: 0.2816 - accuracy: 0.9112 - val_loss: 0.3978 - val_accuracy: 0.8527
# Epoch 4/15
# 150/150 [==============================] - 89s 590ms/step - loss: 0.2390 - accuracy: 0.9194 - val_loss: 0.2665 - val_accuracy: 0.9091
# Epoch 5/15
# 150/150 [==============================] - 89s 591ms/step - loss: 0.2216 - accuracy: 0.9256 - val_loss: 0.2147 - val_accuracy: 0.9268
# Epoch 6/15
# 150/150 [==============================] - 89s 590ms/step - loss: 0.2047 - accuracy: 0.9348 - val_loss: 0.1761 - val_accuracy: 0.9428
# Epoch 7/15
# 150/150 [==============================] - 89s 594ms/step - loss: 0.1979 - accuracy: 0.9381 - val_loss: 0.2418 - val_accuracy: 0.9343
# Epoch 8/15
# 150/150 [==============================] - 89s 589ms/step - loss: 0.1898 - accuracy: 0.9442 - val_loss: 0.2948 - val_accuracy: 0.9352
# Epoch 9/15
# 150/150 [==============================] - 88s 587ms/step - loss: 0.1831 - accuracy: 0.9396 - val_loss: 0.1562 - val_accuracy: 0.9428
# Epoch 10/15
# 150/150 [==============================] - 88s 583ms/step - loss: 0.1705 - accuracy: 0.9435 - val_loss: 0.1861 - val_accuracy: 0.9444
# Epoch 11/15
# 150/150 [==============================] - 88s 587ms/step - loss: 0.1675 - accuracy: 0.9431 - val_loss: 0.1873 - val_accuracy: 0.9444
# Epoch 12/15
# 150/150 [==============================] - 88s 584ms/step - loss: 0.1642 - accuracy: 0.9429 - val_loss: 0.1864 - val_accuracy: 0.9444
# Epoch 13/15
# 150/150 [==============================] - 87s 577ms/step - loss: 0.1460 - accuracy: 0.9504 - val_loss: 0.1347 - val_accuracy: 0.9562
# Epoch 14/15
# 150/150 [==============================] - 87s 578ms/step - loss: 0.1377 - accuracy: 0.9529 - val_loss: 0.1366 - val_accuracy: 0.9529
# Epoch 15/15
# 150/150 [==============================] - 87s 577ms/step - loss: 0.1241 - accuracy: 0.9556 - val_loss: 0.1400 - val_accuracy: 0.9588

# %%
# plot the accuracy of the model
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# plot the loss of the model
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(['train','val'], loc='upper left')
plt.show()

# save the model
model.save("/kaggle/working/face_mask_detection.h5")
